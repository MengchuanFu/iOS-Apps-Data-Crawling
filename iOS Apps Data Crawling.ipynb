# %% [markdown]
# # iOS Apps Data Crawling

# %% [markdown]
# <br />Mengchuan (Mike) Fu     mfu10@fordham.edu October 2016 <br /><br />
# For the Mobile Safety Research<br /><br />

# %% [markdown]
# ## Beautiful Soup

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.

# %% [markdown]
# ## Crawling

# %% [markdown]
# This code crawls Apps data from Apple App Store. The data contains Apps' title, description, version, reviews, maturity rating, reason of maturity rating, related Apps, App's image url, App's rating

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib
import json
import re 

URL = 'https://itunes.apple.com/us/genre/ios-games/id6014?mt=8&letter=Z&page=10#page'
data = urlopen(URL)
soup = BeautifulSoup(data, 'lxml')
url_final = []
for link in soup.find_all(attrs={'class':'column'}):
    for url_info in link.find_all('a'):
        if url_info.get('href').startswith('https://itunes.apple.com/us/app'):
            print ('url=','\t',url_info.get('href'))

            url = url_info.get('href')
            res = requests.get(url)
            res.raise_for_status()
            content = res.content
            final_soup = BeautifulSoup(content,'lxml')
            description = str()
            review_ti = str()
            review_co = str()
            title = str()
            age = str()
            relate = str()
            img = str()
            version = str()
            rate = str()
            rating_num = str()
            star = str()
            age_reason = str()
            
            for text in final_soup.find_all('h1',{'itemprop':'name'}):
                title = title+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'","'").replace('b"','"')    
            
          
            for text in final_soup.find_all('span',{'itemprop':'softwareVersion'}):
                version = version+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'","'").replace('b"','"')    
            
            for text in final_soup.find_all('p',{'itemprop':'description'}):
                description = description+str(text.getText().encode('ASCII', 'ignore')
                                              .strip()).replace("b'"," ").replace('b"','"')
            for text in final_soup.find_all('span',{'class':'customerReviewTitle'}):
                review_ti = review_ti+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'"," ").replace('b"','"')
            for text in final_soup.find_all('p',{'class':'content'}):
                review_co = review_co+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'"," ").replace('b"','"')
            for text in final_soup.find_all('div',{'class':'app-rating'}):
                age = age+str(text.getText().encode('ASCII', 'ignore')
                              .strip()).replace("b'"," ").replace('b"','"').replace("'","")
            
            for text in final_soup.find_all('ul',{'class':'list app-rating-reasons'}):
                age_reason = age_reason+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'","'").replace('b"','"') 
            
            
            for text in final_soup.find_all('div',{'class':'extra-list more-by'}):
                relate = relate+str(text.getText().encode('ASCII', 'ignore')
                                    .strip()).replace("b'"," ").replace('b"','"').replace('View in Mac App Store','')

       
            for text in final_soup.find_all('meta',{'itemprop':'image'}):
                url_image = text
                
            for text in final_soup.find_all('span',{'class':'rating-count'}):
                rating_num = rating_num+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'","'").replace('b"','"')
            
            for text in final_soup.find_all('span',{'itemprop':'ratingValue'}):
                star = star+str(text.getText().encode('ASCII', 'ignore').strip()).replace("b'","'").replace('b"','"') 
            
            

            #print(title)

            with open ('crawler_games.txt','a',encoding='utf-8') as csvfile:
                 csvfile.write(str(title)+'\t'+str(description)+'\t'+str(version)+'\t'+str(review_ti)+'\t'
                               +str(review_co)+'\t'+str(age)+'\t'+str(age_reason)+'\t'+str(relate)+'\t'
                               +str(url_image)+'\t'+str(rating_num)+'\t'+str(star)+'\n')
            with open ('url_final.txt','a',encoding='utf-8') as csvfile:
                 csvfile.write(str(url)+'\n')

        else:
            continue
# Out:
# url= 	 https://itunes.apple.com/us/app/zombie-gravedigger-chase-run-jump-dash-cemetery-undertaker/id791501482?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-graveyard-escape/id1057167487?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-graveyard-shooting-vr-games-pro-ads-free-3d/id1190021216?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-graveyard-shooting-dark-halloween-survival/id1158520312?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gravity/id894822606?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gun-down/id813499384?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gunner-defense/id1076154339?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gunship-arcade/id852187765?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gunship-free-gun-down-zombies/id778141863?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-gunship-gun-down-zombies/id435797419?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hal-fly-like-a-bird/id824019183?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-dash/id728087658?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-jigsaw-puzzle/id1163576810?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-kung-fu-fist-despicable-games-for/id1050056866?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-kung-fu-fist-survival-fighting-games/id1050059870?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-world-war-attack-best-strategy-rpg/id1016162682?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-no-ads-pumpkin-patch-fun-games/id723678473?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-halloween-pumpkin-patch-fun-games/id562243023?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hammer/id722772039?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hand-swipe-pro-match-arrows-that-is-made-human/id912153620?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-harlem-shake-game/id630514359?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-harvest/id959967583?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-haunted-mansion/id853734292?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hazard/id1027259834?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-ahead-beware-of-the-dead-free/id938199207?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-ahead-beware-of-the-dead-pro/id938199236?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-burst-blast-free-monster-hitting-frenzy/id940983786?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-hoops-basketball-skill-shot-training/id661657197?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-lob/id930850077?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-head-surgeon-treat-crazy-zombies-in-doctor-clinic/id939940293?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-headquarters-lone-survivor/id1129602733?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-heads-a-ghoulish-matching-game/id419265210?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell/id586118727?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-2/id1198517109?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-2-zombie-shooting-game/id952124994?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-3/id1167283967?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-3-fps-zombie-game/id1151712826?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-war-3-the-walking-last-empire/id1198873680?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hell-free-frontier-shooting-fighting-games/id1146364032?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-helo/id581017168?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hero/id852376163?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hero-kiki-strikes-back/id1161420911?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hero-fight-with-tank/id1192680525?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-heroes/id704173886?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-heroes-smash/id1163665160?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-heroes-toon-town-monster-shooter-sniper-dead/id1029330709?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hexa-heads-survival-puzzle/id734328320?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-high-dive/id653398045?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway/id376412160?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-last-battle-with-evil/id1104921130?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-2/id892092770?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-apocalypse-shooter-shoot-kill-walking/id1089897658?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-death-racer/id1171326198?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-killer-2017/id1170766543?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-killer-squad-roadkill-rider-3d-killing/id1112486905?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-race-and-kill/id1137159053?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-road-race-out-run-zombies-on-your-go/id655532153?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-roadkill/id1162133871?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-roadkill-drive-and-kills/id1128179461?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-run-for-life/id979913420?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-smasher/id893944363?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-traffic-rider-smart-edition/id1160662983?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-traffic-rider-ii-insane-racing-in-car/id1088795839?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-traffic-rider-best-car-racing-apocalypse/id1082095201?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-trolley-racing-my-pet-zombie-life-multiplayer/id778210061?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-drivers-ed/id675881421?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-highway-drivers-ed-free/id722452005?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hill-run-mega-assault-race-challenge/id892550301?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hill-run-pro-mega-assault-race-challenge/id892550664?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hilo-free-card-game/id960997273?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hit/id1084405350?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hitman-adventure-lite/id810023042?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hitman-adventure-pro/id829671499?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hitman-open-fire-in-zombies-massacre-adventures/id1113496766?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hitter/id904861122?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hive/id1014411316?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hockey/id403020703?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-holideath-a-living-dead-christmas/id741520052?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hoops-by-webfoot/id675860797?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hop-jump-find-the-mega-brains/id509864756?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hop-2-fun-free-jumpy-classic-arcade-adventure-games/id800784441?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-horde-magic-battle-glory-of-the-kingdom/id1100110647?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-horde-shooter/id993502506?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-horde-survivor/id1178413500?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-horde-survivor-pro/id1178415512?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hordes-free/id505178703?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-horror-maze/id1090598040?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hospital-escape-3d-horror-fps-style-shoot-n/id1139689890?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hot-slots-free-horror-slot-machines-game-zombies/id799567338?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-house-reach/id1052653912?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hq/id524110605?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunt-shoot-the-walking-zombies/id875687783?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunt-archery-bow-arrow-game/id1144817430?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunt-hd/id727838248?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunt-pro/id851846030?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunt-simulator-reload-gun-shoot-down-these-evil/id888697078?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-halloween-pro/id1170806483?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-shooting-games/id725378656?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-assassin-lite/id603113026?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-survival-miracle/id1130151590?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-the-dead-land/id1109874231?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-3d-top-sniper-shooting-game/id875267253?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-apocalypse-of-experiment-z-plus/id633017996?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-dead-rising/id1190563426?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-assassin-team-new-monster-target-firing-game/id1017658445?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-assassin-team-pro-new-monster-target/id1017662851?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-attack-on-desert-town-final-defence/id1193812541?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-bike/id964073775?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-breaker/id1114753852?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-bubble-shooter/id1109731164?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-doctor-frank-pro-best-monster-shooter/id1018096146?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-eddy/id1035328974?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-game/id1164090374?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-league/id945123886?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-lite/id518563623?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-mike/id1163743461?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-wild-brain-eater-games-madness-rush-edition/id1083326964?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-shoot-bubble/id1044059462?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-wild-brain-eater-games-madness-rush-edition/id1083326964?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-shoot-bubble/id1044059462?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-shooter-fighter/id1048024092?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-snipe/id940616981?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-sniper/id923706366?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-strike/id1167891112?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-to-survive-games/id1186639613?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-vr/id995907808?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-apocalypse-sniper-of-the-dead/id853087449?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-city-apocalypse-3d/id1193871858?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-death-to-the-undead/id1078167849?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunter-killer-squad-war-survival/id1123957407?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-assassin/id599309345?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunters-3d-elite-ops/id944696371?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunters-pro/id1158151701?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-3d-horror-sniper-hunter-fps-shoot/id1161250711?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-2014-3d-sniper-hunter-fps-shooter-killing/id785281039?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-club-metro-trigger-run/id793816021?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-boat-safari-3d/id1144805536?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-boat-safari-3d-full/id1144805541?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-car-safari-3d/id1141335902?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hunting-car-safari-3d-full/id1141336439?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-hurdles-lite/id560950218?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-huter-ironman-vs-zombies/id1074216476?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-ice-cream-factory-simulator-learn-how-to-make/id1073314220?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-in-fire/id921942188?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-in-vegas-casino-7-royale-free-dont-get-spooked/id719880643?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-infect/id985869745?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-infection/id1104020800?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-infectonator-plague-infect-them-all-incremental/id1066959614?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-infestation/id909378476?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-intern/id1067856977?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invader/id877775947?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion/id295196005?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-smash-em-all/id1183968822?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-2-hd/id381770235?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-defense/id1177450405?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-free/id1023645742?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-kill-zombies-zombie-killer/id1076200746?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-sniper-3d/id962661640?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-invasion-sniper-3d-pro/id983869635?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-io-opoly/id912226449?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-ipocalypse/id526565335?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-island/id547766378?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-island-zombie-games/id1093119375?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-island-devour-the-city/id1114432734?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jammer-rush-epic-water-highway-trip/id891237277?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jammer-rush-epic-water-highway-trip-free/id891237086?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jeep-gunner/id583716788?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jet-speed-boat-free-multiplayer-fun-friends/id617397443?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jetpack/id828780857?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jetpack-robber/id679515293?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jetpack/id793021070?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jewels/id1033813800?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jewels-match3-jewel-star/id1121047085?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jewels-link-eaten-jewels-connect-match-3/id1131512851?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-jewels-puzzle/id1117466577?mt=8
# url= 	 https://itunes.apple.com/us/app/zombie-judgment-day-f/id895395521?mt=8
